# %%
# =============================
# 1. Setup & Imports
# =============================
import os
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import zipfile

from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam

# =============================
# 2. Extract Dataset
# =============================
zip_path = "/content/archive (3).zip"   # change if your zip has diff name
extract_dir = "/content/archive"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print("✅ Dataset extracted to:", extract_dir)

# =============================
# 3. Load Images
# =============================
import cv2

IMG_SIZE = 64

def load_images_from_folder(folder, img_size):
    data = []
    for img_path in glob(os.path.join(folder, "*")):
        try:
            img = cv2.imread(img_path)
            if img is None:
                continue
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (img_size, img_size))
            data.append(img)
        except:
            pass
    return np.array(data)

# Target folders
folders = [
    os.path.join(extract_dir, "Kolam19 Images/Kolam19 Images"),
    os.path.join(extract_dir, "Kolam29 Images/Kolam29 Images"),
    os.path.join(extract_dir, "Kolam109 Images/Kolam109 Images")
]

images = []
for f in folders:
    images.extend(load_images_from_folder(f, IMG_SIZE))

images = np.array(images)
images = (images.astype(np.float32) - 127.5) / 127.5   # normalize to [-1,1]

print("✅ Dataset shape:", images.shape)

# =============================
# 4. GAN Model
# =============================
img_shape = (IMG_SIZE, IMG_SIZE, 3)
latent_dim = 100

# Generator
def build_generator():
    model = Sequential()
    model.add(Dense(256, input_dim=latent_dim))
    model.add(LeakyReLU(0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(512))
    model.add(LeakyReLU(0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(1024))
    model.add(LeakyReLU(0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(np.prod(img_shape), activation='tanh'))
    model.add(Reshape(img_shape))
    return model

# Discriminator
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=img_shape))
    model.add(Dense(512))
    model.add(LeakyReLU(0.2))
    model.add(Dense(256))
    model.add(LeakyReLU(0.2))
    model.add(Dense(1, activation='sigmoid'))
    return model

optimizer = Adam(0.0002, 0.5)

discriminator = build_discriminator()
discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

generator = build_generator()

z = Input(shape=(latent_dim,))
img = generator(z)
discriminator.trainable = False
valid = discriminator(img)

combined = Model(z, valid)
combined.compile(loss='binary_crossentropy', optimizer=optimizer)

# =============================
# 5. Training
# =============================
def save_imgs(epoch):
    r, c = 3, 3
    noise = np.random.normal(0, 1, (r * c, latent_dim))
    gen_imgs = generator.predict(noise)

    gen_imgs = 0.5 * gen_imgs + 0.5  # scale back to [0,1]

    fig, axs = plt.subplots(r, c, figsize=(6,6))
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(gen_imgs[cnt])
            axs[i,j].axis('off')
            cnt += 1
    plt.savefig(f"/content/kolam_{epoch}.png")
    plt.close()

def train(dataset, epochs, batch_size=32, sample_interval=50):
    half = batch_size // 2
    for epoch in range(epochs):

        # Train Discriminator
        idx = np.random.randint(0, dataset.shape[0], half)
        imgs = dataset[idx]

        noise = np.random.normal(0, 1, (half, latent_dim))
        gen_imgs = generator.predict(noise)

        d_loss_real = discriminator.train_on_batch(imgs, np.ones((half, 1)))
        d_loss_fake = discriminator.train_on_batch(gen_imgs, np.zeros((half, 1)))
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Train Generator
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        valid_y = np.ones((batch_size, 1))
        g_loss = combined.train_on_batch(noise, valid_y)

        # Print Progress
        print(f"{epoch} [D loss: {d_loss[0]:.4f}, acc.: {100*d_loss[1]:.2f}%] [G loss: {g_loss:.4f}]")

        # Save images
        if epoch % sample_interval == 0:
            save_imgs(epoch)

# =============================
# 6. Run Training
# =============================
train(images, epochs=2000, batch_size=32, sample_interval=200)
# Out:
# ✅ Dataset extracted to: /content/archive
# ✅ Dataset shape: (600, 64, 64, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 0 [D loss: 0.8504, acc.: 14.06%] [G loss: 0.9857]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1 [D loss: 0.8499, acc.: 19.01%] [G loss: 0.8900]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 2 [D loss: 0.8458, acc.: 18.75%] [G loss: 0.8115]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 3 [D loss: 0.8400, acc.: 17.47%] [G loss: 0.7433]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 4 [D loss: 0.8426, acc.: 15.17%] [G loss: 0.6785]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 5 [D loss: 0.8580, acc.: 12.52%] [G loss: 0.6244]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 6 [D loss: 0.8693, acc.: 11.13%] [G loss: 0.5739]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 7 [D loss: 0.8979, acc.: 9.69%] [G loss: 0.5318]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 8 [D loss: 0.9225, acc.: 8.58%] [G loss: 0.4950]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 9 [D loss: 0.9537, acc.: 7.70%] [G loss: 0.4617]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 10 [D loss: 0.9860, acc.: 7.85%] [G loss: 0.4323]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 11 [D loss: 1.0272, acc.: 7.45%] [G loss: 0.4061]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 12 [D loss: 1.0656, acc.: 7.11%] [G loss: 0.3840]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 13 [D loss: 1.1076, acc.: 6.59%] [G loss: 0.3631]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 14 [D loss: 1.1478, acc.: 6.36%] [G loss: 0.3438]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 15 [D loss: 1.1816, acc.: 6.15%] [G loss: 0.3270]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 16 [D loss: 1.2173, acc.: 5.97%] [G loss: 0.3117]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 17 [D loss: 1.2548, acc.: 5.63%] [G loss: 0.2981]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 18 [D loss: 1.2902, acc.: 5.50%] [G loss: 0.2855]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 19 [D loss: 1.3289, acc.: 5.22%] [G loss: 0.2736]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 20 [D loss: 1.3702, acc.: 4.97%] [G loss: 0.2633]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 21 [D loss: 1.4091, acc.: 4.74%] [G loss: 0.2534]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 22 [D loss: 1.4414, acc.: 4.53%] [G loss: 0.2444]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 23 [D loss: 1.4751, acc.: 4.34%] [G loss: 0.2356]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 24 [D loss: 1.5058, acc.: 4.17%] [G loss: 0.2273]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 25 [D loss: 1.5312, acc.: 4.13%] [G loss: 0.2199]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 26 [D loss: 1.5592, acc.: 4.21%] [G loss: 0.2132]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 27 [D loss: 1.5875, acc.: 4.17%] [G loss: 0.2065]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 28 [D loss: 1.6167, acc.: 4.02%] [G loss: 0.2003]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 29 [D loss: 1.6460, acc.: 4.10%] [G loss: 0.1946]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 30 [D loss: 1.6739, acc.: 3.96%] [G loss: 0.1890]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 31 [D loss: 1.7036, acc.: 3.84%] [G loss: 0.1840]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 32 [D loss: 1.7318, acc.: 3.72%] [G loss: 0.1791]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 33 [D loss: 1.7520, acc.: 3.61%] [G loss: 0.1745]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 34 [D loss: 1.7713, acc.: 3.60%] [G loss: 0.1702]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 35 [D loss: 1.7979, acc.: 3.50%] [G loss: 0.1661]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 36 [D loss: 1.8245, acc.: 3.49%] [G loss: 0.1622]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 37 [D loss: 1.8461, acc.: 3.39%] [G loss: 0.1584]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 38 [D loss: 1.8670, acc.: 3.31%] [G loss: 0.1549]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 39 [D loss: 1.8883, acc.: 3.30%] [G loss: 0.1515]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 40 [D loss: 1.9081, acc.: 3.22%] [G loss: 0.1483]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 41 [D loss: 1.9277, acc.: 3.22%] [G loss: 0.1451]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 42 [D loss: 1.9462, acc.: 3.14%] [G loss: 0.1422]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 43 [D loss: 1.9662, acc.: 3.07%] [G loss: 0.1392]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 44 [D loss: 1.9848, acc.: 3.07%] [G loss: 0.1365]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 45 [D loss: 2.0034, acc.: 3.14%] [G loss: 0.1338]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 46 [D loss: 2.0235, acc.: 3.07%] [G loss: 0.1312]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 47 [D loss: 2.0410, acc.: 3.01%] [G loss: 0.1288]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 48 [D loss: 2.0582, acc.: 2.95%] [G loss: 0.1264]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 49 [D loss: 2.0762, acc.: 2.95%] [G loss: 0.1240]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 50 [D loss: 2.0926, acc.: 2.96%] [G loss: 0.1218]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 51 [D loss: 2.1099, acc.: 2.96%] [G loss: 0.1197]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 52 [D loss: 2.1261, acc.: 2.90%] [G loss: 0.1176]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 53 [D loss: 2.1434, acc.: 2.85%] [G loss: 0.1157]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 54 [D loss: 2.1587, acc.: 2.80%] [G loss: 0.1138]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 55 [D loss: 2.1732, acc.: 2.75%] [G loss: 0.1119]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 56 [D loss: 2.1883, acc.: 2.75%] [G loss: 0.1101]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 57 [D loss: 2.2002, acc.: 2.71%] [G loss: 0.1084]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 58 [D loss: 2.2128, acc.: 2.66%] [G loss: 0.1067]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 59 [D loss: 2.2271, acc.: 2.62%] [G loss: 0.1051]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 60 [D loss: 2.2427, acc.: 2.57%] [G loss: 0.1036]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 61 [D loss: 2.2578, acc.: 2.58%] [G loss: 0.1020]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 62 [D loss: 2.2726, acc.: 2.64%] [G loss: 0.1005]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 63 [D loss: 2.2880, acc.: 2.60%] [G loss: 0.0990]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 64 [D loss: 2.3004, acc.: 2.61%] [G loss: 0.0977]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 65 [D loss: 2.3118, acc.: 2.57%] [G loss: 0.0963]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 66 [D loss: 2.3263, acc.: 2.57%] [G loss: 0.0949]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 67 [D loss: 2.3398, acc.: 2.58%] [G loss: 0.0937]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 68 [D loss: 2.3523, acc.: 2.55%] [G loss: 0.0924]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 69 [D loss: 2.3644, acc.: 2.55%] [G loss: 0.0912]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 70 [D loss: 2.3756, acc.: 2.52%] [G loss: 0.0900]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 71 [D loss: 2.3867, acc.: 2.48%] [G loss: 0.0889]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 72 [D loss: 2.3974, acc.: 2.45%] [G loss: 0.0878]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 73 [D loss: 2.4089, acc.: 2.42%] [G loss: 0.0867]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 74 [D loss: 2.4212, acc.: 2.38%] [G loss: 0.0856]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 75 [D loss: 2.4347, acc.: 2.35%] [G loss: 0.0846]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 76 [D loss: 2.4472, acc.: 2.36%] [G loss: 0.0836]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 77 [D loss: 2.4578, acc.: 2.33%] [G loss: 0.0826]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 78 [D loss: 2.4686, acc.: 2.30%] [G loss: 0.0816]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 79 [D loss: 2.4795, acc.: 2.31%] [G loss: 0.0806]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 80 [D loss: 2.4900, acc.: 2.28%] [G loss: 0.0797]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 81 [D loss: 2.5003, acc.: 2.29%] [G loss: 0.0788]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 82 [D loss: 2.5106, acc.: 2.27%] [G loss: 0.0780]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 83 [D loss: 2.5203, acc.: 2.24%] [G loss: 0.0771]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 84 [D loss: 2.5306, acc.: 2.25%] [G loss: 0.0763]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 85 [D loss: 2.5404, acc.: 2.22%] [G loss: 0.0754]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 86 [D loss: 2.5505, acc.: 2.20%] [G loss: 0.0746]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 87 [D loss: 2.5606, acc.: 2.17%] [G loss: 0.0738]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 88 [D loss: 2.5707, acc.: 2.18%] [G loss: 0.0730]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 89 [D loss: 2.5808, acc.: 2.19%] [G loss: 0.0723]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 90 [D loss: 2.5919, acc.: 2.20%] [G loss: 0.0715]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 91 [D loss: 2.6038, acc.: 2.18%] [G loss: 0.0708]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 92 [D loss: 2.6139, acc.: 2.16%] [G loss: 0.0701]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 93 [D loss: 2.6248, acc.: 2.17%] [G loss: 0.0694]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 94 [D loss: 2.6365, acc.: 2.14%] [G loss: 0.0687]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 95 [D loss: 2.6457, acc.: 2.12%] [G loss: 0.0680]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 96 [D loss: 2.6538, acc.: 2.10%] [G loss: 0.0673]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 97 [D loss: 2.6620, acc.: 2.08%] [G loss: 0.0667]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 98 [D loss: 2.6699, acc.: 2.06%] [G loss: 0.0661]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 99 [D loss: 2.6783, acc.: 2.04%] [G loss: 0.0654]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 100 [D loss: 2.6870, acc.: 2.02%] [G loss: 0.0648]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 101 [D loss: 2.6955, acc.: 2.00%] [G loss: 0.0642]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 102 [D loss: 2.7033, acc.: 2.01%] [G loss: 0.0636]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 103 [D loss: 2.7113, acc.: 2.02%] [G loss: 0.0631]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 104 [D loss: 2.7199, acc.: 2.00%] [G loss: 0.0625]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 105 [D loss: 2.7285, acc.: 1.98%] [G loss: 0.0620]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 106 [D loss: 2.7365, acc.: 1.96%] [G loss: 0.0614]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 107 [D loss: 2.7442, acc.: 1.94%] [G loss: 0.0609]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 108 [D loss: 2.7520, acc.: 1.93%] [G loss: 0.0603]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 109 [D loss: 2.7602, acc.: 1.91%] [G loss: 0.0598]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 110 [D loss: 2.7677, acc.: 1.92%] [G loss: 0.0593]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 111 [D loss: 2.7739, acc.: 1.90%] [G loss: 0.0588]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 112 [D loss: 2.7805, acc.: 1.88%] [G loss: 0.0583]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 113 [D loss: 2.7887, acc.: 1.90%] [G loss: 0.0579]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 114 [D loss: 2.7974, acc.: 1.93%] [G loss: 0.0574]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 115 [D loss: 2.8064, acc.: 1.92%] [G loss: 0.0569]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 116 [D loss: 2.8136, acc.: 2.01%] [G loss: 0.0565]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 117 [D loss: 2.8205, acc.: 1.99%] [G loss: 0.0560]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 118 [D loss: 2.8277, acc.: 2.00%] [G loss: 0.0556]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 119 [D loss: 2.8345, acc.: 1.98%] [G loss: 0.0551]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 120 [D loss: 2.8413, acc.: 1.97%] [G loss: 0.0547]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 121 [D loss: 2.8490, acc.: 1.95%] [G loss: 0.0543]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 122 [D loss: 2.8571, acc.: 1.96%] [G loss: 0.0538]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 123 [D loss: 2.8654, acc.: 1.94%] [G loss: 0.0534]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 124 [D loss: 2.8737, acc.: 1.95%] [G loss: 0.0530]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 125 [D loss: 2.8803, acc.: 1.94%] [G loss: 0.0526]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 126 [D loss: 2.8860, acc.: 1.92%] [G loss: 0.0522]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 127 [D loss: 2.8930, acc.: 1.93%] [G loss: 0.0519]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 128 [D loss: 2.8999, acc.: 1.94%] [G loss: 0.0515]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 129 [D loss: 2.9073, acc.: 1.95%] [G loss: 0.0511]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 130 [D loss: 2.9142, acc.: 1.94%] [G loss: 0.0507]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 131 [D loss: 2.9208, acc.: 1.92%] [G loss: 0.0504]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 132 [D loss: 2.9284, acc.: 1.91%] [G loss: 0.0500]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 133 [D loss: 2.9349, acc.: 1.89%] [G loss: 0.0497]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 134 [D loss: 2.9413, acc.: 1.88%] [G loss: 0.0493]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 135 [D loss: 2.9480, acc.: 1.86%] [G loss: 0.0490]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 136 [D loss: 2.9544, acc.: 1.85%] [G loss: 0.0486]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 137 [D loss: 2.9614, acc.: 1.84%] [G loss: 0.0483]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 138 [D loss: 2.9682, acc.: 1.82%] [G loss: 0.0480]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 139 [D loss: 2.9740, acc.: 1.81%] [G loss: 0.0476]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 140 [D loss: 2.9810, acc.: 1.80%] [G loss: 0.0473]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 141 [D loss: 2.9888, acc.: 1.79%] [G loss: 0.0470]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 142 [D loss: 2.9951, acc.: 1.80%] [G loss: 0.0467]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 143 [D loss: 3.0009, acc.: 1.78%] [G loss: 0.0464]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 144 [D loss: 3.0067, acc.: 1.77%] [G loss: 0.0461]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 145 [D loss: 3.0118, acc.: 1.76%] [G loss: 0.0458]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 146 [D loss: 3.0170, acc.: 1.75%] [G loss: 0.0455]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 147 [D loss: 3.0233, acc.: 1.73%] [G loss: 0.0452]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 148 [D loss: 3.0297, acc.: 1.74%] [G loss: 0.0449]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 149 [D loss: 3.0361, acc.: 1.75%] [G loss: 0.0446]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 150 [D loss: 3.0427, acc.: 1.76%] [G loss: 0.0443]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 151 [D loss: 3.0483, acc.: 1.75%] [G loss: 0.0440]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 152 [D loss: 3.0534, acc.: 1.74%] [G loss: 0.0438]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 153 [D loss: 3.0592, acc.: 1.73%] [G loss: 0.0435]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 154 [D loss: 3.0650, acc.: 1.72%] [G loss: 0.0432]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 155 [D loss: 3.0695, acc.: 1.73%] [G loss: 0.0430]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 156 [D loss: 3.0743, acc.: 1.71%] [G loss: 0.0427]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 157 [D loss: 3.0804, acc.: 1.70%] [G loss: 0.0424]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 158 [D loss: 3.0871, acc.: 1.69%] [G loss: 0.0422]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 159 [D loss: 3.0936, acc.: 1.74%] [G loss: 0.0419]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 160 [D loss: 3.0996, acc.: 1.75%] [G loss: 0.0417]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 161 [D loss: 3.1050, acc.: 1.74%] [G loss: 0.0414]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 162 [D loss: 3.1101, acc.: 1.73%] [G loss: 0.0412]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 163 [D loss: 3.1153, acc.: 1.74%] [G loss: 0.0409]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 164 [D loss: 3.1205, acc.: 1.75%] [G loss: 0.0407]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 165 [D loss: 3.1261, acc.: 1.77%] [G loss: 0.0405]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 166 [D loss: 3.1319, acc.: 1.76%] [G loss: 0.0402]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 167 [D loss: 3.1371, acc.: 1.75%] [G loss: 0.0400]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 168 [D loss: 3.1418, acc.: 1.74%] [G loss: 0.0398]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 169 [D loss: 3.1461, acc.: 1.75%] [G loss: 0.0396]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 170 [D loss: 3.1509, acc.: 1.76%] [G loss: 0.0393]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 171 [D loss: 3.1558, acc.: 1.76%] [G loss: 0.0391]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 172 [D loss: 3.1608, acc.: 1.75%] [G loss: 0.0389]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 173 [D loss: 3.1660, acc.: 1.74%] [G loss: 0.0387]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 174 [D loss: 3.1715, acc.: 1.73%] [G loss: 0.0385]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 175 [D loss: 3.1767, acc.: 1.74%] [G loss: 0.0383]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 176 [D loss: 3.1824, acc.: 1.75%] [G loss: 0.0381]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 177 [D loss: 3.1874, acc.: 1.79%] [G loss: 0.0378]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 178 [D loss: 3.1923, acc.: 1.80%] [G loss: 0.0376]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 179 [D loss: 3.1978, acc.: 1.79%] [G loss: 0.0374]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 180 [D loss: 3.2024, acc.: 1.82%] [G loss: 0.0372]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 181 [D loss: 3.2067, acc.: 1.81%] [G loss: 0.0370]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 182 [D loss: 3.2115, acc.: 1.80%] [G loss: 0.0369]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 183 [D loss: 3.2158, acc.: 1.79%] [G loss: 0.0367]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 184 [D loss: 3.2200, acc.: 1.79%] [G loss: 0.0365]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 185 [D loss: 3.2248, acc.: 1.78%] [G loss: 0.0363]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 186 [D loss: 3.2292, acc.: 1.79%] [G loss: 0.0361]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 187 [D loss: 3.2340, acc.: 1.80%] [G loss: 0.0359]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 188 [D loss: 3.2385, acc.: 1.82%] [G loss: 0.0357]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 189 [D loss: 3.2430, acc.: 1.83%] [G loss: 0.0356]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 190 [D loss: 3.2473, acc.: 1.83%] [G loss: 0.0354]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 191 [D loss: 3.2514, acc.: 1.83%] [G loss: 0.0352]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 192 [D loss: 3.2556, acc.: 1.82%] [G loss: 0.0350]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 193 [D loss: 3.2593, acc.: 1.84%] [G loss: 0.0348]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 194 [D loss: 3.2634, acc.: 1.83%] [G loss: 0.0347]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 195 [D loss: 3.2684, acc.: 1.82%] [G loss: 0.0345]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 196 [D loss: 3.2732, acc.: 1.81%] [G loss: 0.0343]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 197 [D loss: 3.2783, acc.: 1.80%] [G loss: 0.0342]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 198 [D loss: 3.2824, acc.: 1.79%] [G loss: 0.0340]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 199 [D loss: 3.2868, acc.: 1.78%] [G loss: 0.0338]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 200 [D loss: 3.2923, acc.: 1.77%] [G loss: 0.0337]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 201 [D loss: 3.2979, acc.: 1.77%] [G loss: 0.0335]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 202 [D loss: 3.3028, acc.: 1.77%] [G loss: 0.0334]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 203 [D loss: 3.3075, acc.: 1.78%] [G loss: 0.0332]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 204 [D loss: 3.3129, acc.: 1.79%] [G loss: 0.0331]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 205 [D loss: 3.3172, acc.: 1.79%] [G loss: 0.0329]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 206 [D loss: 3.3207, acc.: 1.80%] [G loss: 0.0327]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 207 [D loss: 3.3251, acc.: 1.79%] [G loss: 0.0326]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 208 [D loss: 3.3302, acc.: 1.78%] [G loss: 0.0324]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 209 [D loss: 3.3349, acc.: 1.77%] [G loss: 0.0323]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 210 [D loss: 3.3390, acc.: 1.78%] [G loss: 0.0322]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 211 [D loss: 3.3434, acc.: 1.77%] [G loss: 0.0320]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 212 [D loss: 3.3461, acc.: 1.76%] [G loss: 0.0319]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 213 [D loss: 3.3488, acc.: 1.75%] [G loss: 0.0317]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 214 [D loss: 3.3527, acc.: 1.75%] [G loss: 0.0316]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 215 [D loss: 3.3567, acc.: 1.74%] [G loss: 0.0314]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 216 [D loss: 3.3607, acc.: 1.73%] [G loss: 0.0313]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 217 [D loss: 3.3646, acc.: 1.74%] [G loss: 0.0312]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 218 [D loss: 3.3688, acc.: 1.73%] [G loss: 0.0310]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 219 [D loss: 3.3736, acc.: 1.72%] [G loss: 0.0309]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 220 [D loss: 3.3778, acc.: 1.74%] [G loss: 0.0307]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 221 [D loss: 3.3814, acc.: 1.73%] [G loss: 0.0306]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 222 [D loss: 3.3852, acc.: 1.73%] [G loss: 0.0305]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 223 [D loss: 3.3892, acc.: 1.72%] [G loss: 0.0304]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 224 [D loss: 3.3931, acc.: 1.72%] [G loss: 0.0302]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 225 [D loss: 3.3976, acc.: 1.72%] [G loss: 0.0301]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 226 [D loss: 3.4017, acc.: 1.71%] [G loss: 0.0300]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 227 [D loss: 3.4051, acc.: 1.72%] [G loss: 0.0298]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 228 [D loss: 3.4088, acc.: 1.71%] [G loss: 0.0297]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 229 [D loss: 3.4126, acc.: 1.71%] [G loss: 0.0296]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 230 [D loss: 3.4167, acc.: 1.72%] [G loss: 0.0295]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 231 [D loss: 3.4208, acc.: 1.71%] [G loss: 0.0293]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 232 [D loss: 3.4247, acc.: 1.71%] [G loss: 0.0292]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 233 [D loss: 3.4287, acc.: 1.70%] [G loss: 0.0291]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 234 [D loss: 3.4323, acc.: 1.70%] [G loss: 0.0290]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 235 [D loss: 3.4360, acc.: 1.70%] [G loss: 0.0289]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 236 [D loss: 3.4394, acc.: 1.70%] [G loss: 0.0287]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 237 [D loss: 3.4428, acc.: 1.70%] [G loss: 0.0286]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 238 [D loss: 3.4469, acc.: 1.69%] [G loss: 0.0285]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 239 [D loss: 3.4508, acc.: 1.68%] [G loss: 0.0284]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 240 [D loss: 3.4545, acc.: 1.67%] [G loss: 0.0283]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 241 [D loss: 3.4580, acc.: 1.68%] [G loss: 0.0282]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 242 [D loss: 3.4614, acc.: 1.69%] [G loss: 0.0281]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 243 [D loss: 3.4649, acc.: 1.69%] [G loss: 0.0279]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 244 [D loss: 3.4685, acc.: 1.69%] [G loss: 0.0278]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 245 [D loss: 3.4717, acc.: 1.68%] [G loss: 0.0277]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 246 [D loss: 3.4748, acc.: 1.67%] [G loss: 0.0276]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 247 [D loss: 3.4786, acc.: 1.66%] [G loss: 0.0275]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 248 [D loss: 3.4825, acc.: 1.66%] [G loss: 0.0274]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 249 [D loss: 3.4857, acc.: 1.66%] [G loss: 0.0273]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 250 [D loss: 3.4891, acc.: 1.66%] [G loss: 0.0272]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 251 [D loss: 3.4927, acc.: 1.65%] [G loss: 0.0271]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 252 [D loss: 3.4968, acc.: 1.64%] [G loss: 0.0270]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 253 [D loss: 3.5012, acc.: 1.65%] [G loss: 0.0269]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 254 [D loss: 3.5055, acc.: 1.64%] [G loss: 0.0268]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 255 [D loss: 3.5093, acc.: 1.64%] [G loss: 0.0267]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 256 [D loss: 3.5135, acc.: 1.64%] [G loss: 0.0266]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 257 [D loss: 3.5178, acc.: 1.66%] [G loss: 0.0265]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 258 [D loss: 3.5217, acc.: 1.65%] [G loss: 0.0264]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 259 [D loss: 3.5253, acc.: 1.65%] [G loss: 0.0263]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 260 [D loss: 3.5294, acc.: 1.64%] [G loss: 0.0262]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 261 [D loss: 3.5331, acc.: 1.64%] [G loss: 0.0261]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 262 [D loss: 3.5360, acc.: 1.63%] [G loss: 0.0260]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 263 [D loss: 3.5390, acc.: 1.62%] [G loss: 0.0259]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 264 [D loss: 3.5424, acc.: 1.62%] [G loss: 0.0258]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 265 [D loss: 3.5462, acc.: 1.65%] [G loss: 0.0257]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 266 [D loss: 3.5500, acc.: 1.64%] [G loss: 0.0256]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 267 [D loss: 3.5533, acc.: 1.63%] [G loss: 0.0255]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 268 [D loss: 3.5568, acc.: 1.63%] [G loss: 0.0254]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 269 [D loss: 3.5598, acc.: 1.65%] [G loss: 0.0253]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 270 [D loss: 3.5630, acc.: 1.64%] [G loss: 0.0252]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 271 [D loss: 3.5662, acc.: 1.63%] [G loss: 0.0252]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 272 [D loss: 3.5694, acc.: 1.64%] [G loss: 0.0251]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 273 [D loss: 3.5737, acc.: 1.63%] [G loss: 0.0250]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 274 [D loss: 3.5776, acc.: 1.63%] [G loss: 0.0249]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 275 [D loss: 3.5805, acc.: 1.62%] [G loss: 0.0248]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 276 [D loss: 3.5836, acc.: 1.61%] [G loss: 0.0247]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 277 [D loss: 3.5864, acc.: 1.61%] [G loss: 0.0246]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 278 [D loss: 3.5889, acc.: 1.60%] [G loss: 0.0245]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 279 [D loss: 3.5917, acc.: 1.61%] [G loss: 0.0245]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 280 [D loss: 3.5945, acc.: 1.60%] [G loss: 0.0244]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 281 [D loss: 3.5972, acc.: 1.60%] [G loss: 0.0243]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 282 [D loss: 3.6003, acc.: 1.59%] [G loss: 0.0242]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 283 [D loss: 3.6038, acc.: 1.61%] [G loss: 0.0241]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 284 [D loss: 3.6070, acc.: 1.60%] [G loss: 0.0240]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 285 [D loss: 3.6099, acc.: 1.61%] [G loss: 0.0240]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 286 [D loss: 3.6130, acc.: 1.60%] [G loss: 0.0239]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 287 [D loss: 3.6161, acc.: 1.60%] [G loss: 0.0238]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 288 [D loss: 3.6194, acc.: 1.60%] [G loss: 0.0237]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 289 [D loss: 3.6228, acc.: 1.62%] [G loss: 0.0236]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 290 [D loss: 3.6260, acc.: 1.62%] [G loss: 0.0236]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 291 [D loss: 3.6287, acc.: 1.63%] [G loss: 0.0235]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 292 [D loss: 3.6313, acc.: 1.62%] [G loss: 0.0234]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 293 [D loss: 3.6342, acc.: 1.62%] [G loss: 0.0233]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 294 [D loss: 3.6376, acc.: 1.62%] [G loss: 0.0233]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 295 [D loss: 3.6409, acc.: 1.62%] [G loss: 0.0232]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 296 [D loss: 3.6436, acc.: 1.62%] [G loss: 0.0231]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 297 [D loss: 3.6459, acc.: 1.63%] [G loss: 0.0230]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 298 [D loss: 3.6486, acc.: 1.62%] [G loss: 0.0230]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 299 [D loss: 3.6521, acc.: 1.62%] [G loss: 0.0229]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 300 [D loss: 3.6553, acc.: 1.61%] [G loss: 0.0228]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 301 [D loss: 3.6578, acc.: 1.61%] [G loss: 0.0227]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 302 [D loss: 3.6606, acc.: 1.60%] [G loss: 0.0227]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 303 [D loss: 3.6636, acc.: 1.59%] [G loss: 0.0226]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 304 [D loss: 3.6659, acc.: 1.60%] [G loss: 0.0225]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 305 [D loss: 3.6685, acc.: 1.59%] [G loss: 0.0224]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 306 [D loss: 3.6717, acc.: 1.60%] [G loss: 0.0224]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 307 [D loss: 3.6749, acc.: 1.61%] [G loss: 0.0223]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 308 [D loss: 3.6776, acc.: 1.63%] [G loss: 0.0222]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 309 [D loss: 3.6800, acc.: 1.65%] [G loss: 0.0222]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 310 [D loss: 3.6830, acc.: 1.65%] [G loss: 0.0221]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 311 [D loss: 3.6861, acc.: 1.65%] [G loss: 0.0220]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 312 [D loss: 3.6891, acc.: 1.65%] [G loss: 0.0219]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 313 [D loss: 3.6923, acc.: 1.65%] [G loss: 0.0219]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 314 [D loss: 3.6954, acc.: 1.66%] [G loss: 0.0218]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 315 [D loss: 3.6981, acc.: 1.65%] [G loss: 0.0217]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 316 [D loss: 3.7010, acc.: 1.65%] [G loss: 0.0217]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 317 [D loss: 3.7037, acc.: 1.64%] [G loss: 0.0216]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 318 [D loss: 3.7068, acc.: 1.64%] [G loss: 0.0215]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 319 [D loss: 3.7092, acc.: 1.63%] [G loss: 0.0215]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 320 [D loss: 3.7115, acc.: 1.63%] [G loss: 0.0214]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 321 [D loss: 3.7144, acc.: 1.63%] [G loss: 0.0214]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 322 [D loss: 3.7175, acc.: 1.65%] [G loss: 0.0213]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 323 [D loss: 3.7204, acc.: 1.64%] [G loss: 0.0212]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 324 [D loss: 3.7234, acc.: 1.65%] [G loss: 0.0212]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 325 [D loss: 3.7264, acc.: 1.67%] [G loss: 0.0211]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 326 [D loss: 3.7296, acc.: 1.68%] [G loss: 0.0210]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 327 [D loss: 3.7327, acc.: 1.68%] [G loss: 0.0210]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 328 [D loss: 3.7354, acc.: 1.67%] [G loss: 0.0209]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 329 [D loss: 3.7383, acc.: 1.67%] [G loss: 0.0208]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 330 [D loss: 3.7410, acc.: 1.66%] [G loss: 0.0208]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 331 [D loss: 3.7430, acc.: 1.66%] [G loss: 0.0207]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 332 [D loss: 3.7455, acc.: 1.65%] [G loss: 0.0207]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 333 [D loss: 3.7484, acc.: 1.65%] [G loss: 0.0206]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 334 [D loss: 3.7514, acc.: 1.64%] [G loss: 0.0205]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 335 [D loss: 3.7535, acc.: 1.64%] [G loss: 0.0205]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 336 [D loss: 3.7559, acc.: 1.63%] [G loss: 0.0204]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 337 [D loss: 3.7594, acc.: 1.63%] [G loss: 0.0204]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 338 [D loss: 3.7627, acc.: 1.62%] [G loss: 0.0203]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 339 [D loss: 3.7655, acc.: 1.63%] [G loss: 0.0203]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 340 [D loss: 3.7681, acc.: 1.62%] [G loss: 0.0202]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 341 [D loss: 3.7708, acc.: 1.63%] [G loss: 0.0201]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 342 [D loss: 3.7737, acc.: 1.62%] [G loss: 0.0201]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 343 [D loss: 3.7765, acc.: 1.62%] [G loss: 0.0200]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 344 [D loss: 3.7792, acc.: 1.63%] [G loss: 0.0200]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 345 [D loss: 3.7820, acc.: 1.63%] [G loss: 0.0199]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 346 [D loss: 3.7846, acc.: 1.63%] [G loss: 0.0199]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 347 [D loss: 3.7871, acc.: 1.64%] [G loss: 0.0198]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 348 [D loss: 3.7890, acc.: 1.64%] [G loss: 0.0197]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 349 [D loss: 3.7911, acc.: 1.64%] [G loss: 0.0197]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 350 [D loss: 3.7934, acc.: 1.63%] [G loss: 0.0196]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 351 [D loss: 3.7958, acc.: 1.63%] [G loss: 0.0196]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 352 [D loss: 3.7985, acc.: 1.65%] [G loss: 0.0195]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 353 [D loss: 3.8008, acc.: 1.64%] [G loss: 0.0195]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 354 [D loss: 3.8034, acc.: 1.64%] [G loss: 0.0194]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 355 [D loss: 3.8062, acc.: 1.65%] [G loss: 0.0194]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 356 [D loss: 3.8087, acc.: 1.66%] [G loss: 0.0193]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 357 [D loss: 3.8115, acc.: 1.65%] [G loss: 0.0193]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 358 [D loss: 3.8143, acc.: 1.65%] [G loss: 0.0192]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 359 [D loss: 3.8169, acc.: 1.65%] [G loss: 0.0192]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 360 [D loss: 3.8199, acc.: 1.65%] [G loss: 0.0191]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 361 [D loss: 3.8230, acc.: 1.65%] [G loss: 0.0191]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 362 [D loss: 3.8254, acc.: 1.65%] [G loss: 0.0190]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 363 [D loss: 3.8276, acc.: 1.64%] [G loss: 0.0189]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 364 [D loss: 3.8300, acc.: 1.65%] [G loss: 0.0189]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 365 [D loss: 3.8326, acc.: 1.66%] [G loss: 0.0188]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 366 [D loss: 3.8353, acc.: 1.67%] [G loss: 0.0188]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 367 [D loss: 3.8380, acc.: 1.67%] [G loss: 0.0187]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 368 [D loss: 3.8405, acc.: 1.67%] [G loss: 0.0187]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 369 [D loss: 3.8431, acc.: 1.66%] [G loss: 0.0186]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 370 [D loss: 3.8456, acc.: 1.66%] [G loss: 0.0186]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 371 [D loss: 3.8477, acc.: 1.68%] [G loss: 0.0186]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 372 [D loss: 3.8501, acc.: 1.68%] [G loss: 0.0185]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 373 [D loss: 3.8527, acc.: 1.67%] [G loss: 0.0185]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 374 [D loss: 3.8551, acc.: 1.67%] [G loss: 0.0184]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 375 [D loss: 3.8574, acc.: 1.66%] [G loss: 0.0184]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 376 [D loss: 3.8595, acc.: 1.67%] [G loss: 0.0183]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 377 [D loss: 3.8617, acc.: 1.69%] [G loss: 0.0183]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 378 [D loss: 3.8641, acc.: 1.68%] [G loss: 0.0182]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 379 [D loss: 3.8663, acc.: 1.69%] [G loss: 0.0182]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 380 [D loss: 3.8683, acc.: 1.68%] [G loss: 0.0181]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 381 [D loss: 3.8703, acc.: 1.68%] [G loss: 0.0181]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 382 [D loss: 3.8722, acc.: 1.68%] [G loss: 0.0180]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 383 [D loss: 3.8746, acc.: 1.69%] [G loss: 0.0180]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 384 [D loss: 3.8773, acc.: 1.69%] [G loss: 0.0179]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 385 [D loss: 3.8800, acc.: 1.69%] [G loss: 0.0179]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 386 [D loss: 3.8826, acc.: 1.69%] [G loss: 0.0179]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 387 [D loss: 3.8854, acc.: 1.68%] [G loss: 0.0178]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 388 [D loss: 3.8879, acc.: 1.68%] [G loss: 0.0178]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 389 [D loss: 3.8902, acc.: 1.68%] [G loss: 0.0177]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 390 [D loss: 3.8926, acc.: 1.68%] [G loss: 0.0177]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 391 [D loss: 3.8948, acc.: 1.68%] [G loss: 0.0176]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 392 [D loss: 3.8965, acc.: 1.67%] [G loss: 0.0176]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 393 [D loss: 3.8986, acc.: 1.67%] [G loss: 0.0175]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 394 [D loss: 3.9006, acc.: 1.66%] [G loss: 0.0175]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 395 [D loss: 3.9025, acc.: 1.66%] [G loss: 0.0175]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 396 [D loss: 3.9048, acc.: 1.66%] [G loss: 0.0174]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 397 [D loss: 3.9069, acc.: 1.66%] [G loss: 0.0174]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 398 [D loss: 3.9089, acc.: 1.65%] [G loss: 0.0173]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 399 [D loss: 3.9108, acc.: 1.66%] [G loss: 0.0173]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 400 [D loss: 3.9131, acc.: 1.65%] [G loss: 0.0172]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 401 [D loss: 3.9156, acc.: 1.65%] [G loss: 0.0172]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 402 [D loss: 3.9175, acc.: 1.64%] [G loss: 0.0172]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 403 [D loss: 3.9195, acc.: 1.65%] [G loss: 0.0171]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 404 [D loss: 3.9222, acc.: 1.64%] [G loss: 0.0171]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 405 [D loss: 3.9248, acc.: 1.64%] [G loss: 0.0170]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 406 [D loss: 3.9268, acc.: 1.64%] [G loss: 0.0170]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 407 [D loss: 3.9289, acc.: 1.66%] [G loss: 0.0170]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 408 [D loss: 3.9313, acc.: 1.65%] [G loss: 0.0169]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 409 [D loss: 3.9337, acc.: 1.65%] [G loss: 0.0169]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 410 [D loss: 3.9358, acc.: 1.64%] [G loss: 0.0168]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 411 [D loss: 3.9376, acc.: 1.64%] [G loss: 0.0168]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 412 [D loss: 3.9397, acc.: 1.65%] [G loss: 0.0168]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 413 [D loss: 3.9419, acc.: 1.65%] [G loss: 0.0167]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 414 [D loss: 3.9435, acc.: 1.64%] [G loss: 0.0167]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 415 [D loss: 3.9455, acc.: 1.64%] [G loss: 0.0166]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 416 [D loss: 3.9480, acc.: 1.63%] [G loss: 0.0166]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 417 [D loss: 3.9505, acc.: 1.65%] [G loss: 0.0166]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 418 [D loss: 3.9527, acc.: 1.64%] [G loss: 0.0165]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 419 [D loss: 3.9546, acc.: 1.65%] [G loss: 0.0165]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 420 [D loss: 3.9568, acc.: 1.64%] [G loss: 0.0164]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 421 [D loss: 3.9590, acc.: 1.64%] [G loss: 0.0164]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 422 [D loss: 3.9611, acc.: 1.63%] [G loss: 0.0164]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 423 [D loss: 3.9630, acc.: 1.63%] [G loss: 0.0163]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 424 [D loss: 3.9650, acc.: 1.63%] [G loss: 0.0163]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 425 [D loss: 3.9671, acc.: 1.62%] [G loss: 0.0163]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 426 [D loss: 3.9694, acc.: 1.63%] [G loss: 0.0162]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 427 [D loss: 3.9715, acc.: 1.64%] [G loss: 0.0162]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 428 [D loss: 3.9737, acc.: 1.64%] [G loss: 0.0161]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 429 [D loss: 3.9763, acc.: 1.64%] [G loss: 0.0161]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 430 [D loss: 3.9792, acc.: 1.63%] [G loss: 0.0161]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 431 [D loss: 3.9817, acc.: 1.63%] [G loss: 0.0160]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 432 [D loss: 3.9840, acc.: 1.62%] [G loss: 0.0160]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 433 [D loss: 3.9864, acc.: 1.63%] [G loss: 0.0160]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 434 [D loss: 3.9887, acc.: 1.62%] [G loss: 0.0159]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 435 [D loss: 3.9911, acc.: 1.62%] [G loss: 0.0159]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 436 [D loss: 3.9931, acc.: 1.62%] [G loss: 0.0159]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 437 [D loss: 3.9949, acc.: 1.61%] [G loss: 0.0158]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 438 [D loss: 3.9969, acc.: 1.61%] [G loss: 0.0158]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 439 [D loss: 3.9992, acc.: 1.61%] [G loss: 0.0158]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 440 [D loss: 4.0009, acc.: 1.60%] [G loss: 0.0157]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 441 [D loss: 4.0029, acc.: 1.61%] [G loss: 0.0157]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 442 [D loss: 4.0056, acc.: 1.60%] [G loss: 0.0156]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 443 [D loss: 4.0080, acc.: 1.60%] [G loss: 0.0156]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 444 [D loss: 4.0101, acc.: 1.59%] [G loss: 0.0156]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 445 [D loss: 4.0124, acc.: 1.61%] [G loss: 0.0155]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 446 [D loss: 4.0146, acc.: 1.60%] [G loss: 0.0155]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 447 [D loss: 4.0162, acc.: 1.60%] [G loss: 0.0155]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 448 [D loss: 4.0177, acc.: 1.59%] [G loss: 0.0154]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 449 [D loss: 4.0202, acc.: 1.59%] [G loss: 0.0154]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 450 [D loss: 4.0232, acc.: 1.59%] [G loss: 0.0154]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 451 [D loss: 4.0251, acc.: 1.59%] [G loss: 0.0153]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 452 [D loss: 4.0268, acc.: 1.59%] [G loss: 0.0153]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 453 [D loss: 4.0292, acc.: 1.58%] [G loss: 0.0153]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 454 [D loss: 4.0315, acc.: 1.58%] [G loss: 0.0152]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 455 [D loss: 4.0335, acc.: 1.58%] [G loss: 0.0152]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 456 [D loss: 4.0357, acc.: 1.57%] [G loss: 0.0152]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 457 [D loss: 4.0380, acc.: 1.57%] [G loss: 0.0151]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 458 [D loss: 4.0403, acc.: 1.57%] [G loss: 0.0151]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 459 [D loss: 4.0424, acc.: 1.56%] [G loss: 0.0151]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 460 [D loss: 4.0444, acc.: 1.56%] [G loss: 0.0150]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 461 [D loss: 4.0463, acc.: 1.56%] [G loss: 0.0150]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 462 [D loss: 4.0481, acc.: 1.55%] [G loss: 0.0150]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 463 [D loss: 4.0496, acc.: 1.56%] [G loss: 0.0150]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 464 [D loss: 4.0515, acc.: 1.55%] [G loss: 0.0149]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 465 [D loss: 4.0534, acc.: 1.56%] [G loss: 0.0149]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 466 [D loss: 4.0555, acc.: 1.56%] [G loss: 0.0149]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 467 [D loss: 4.0576, acc.: 1.56%] [G loss: 0.0148]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 468 [D loss: 4.0598, acc.: 1.56%] [G loss: 0.0148]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 469 [D loss: 4.0620, acc.: 1.56%] [G loss: 0.0148]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 470 [D loss: 4.0639, acc.: 1.55%] [G loss: 0.0147]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 471 [D loss: 4.0659, acc.: 1.55%] [G loss: 0.0147]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 472 [D loss: 4.0681, acc.: 1.56%] [G loss: 0.0147]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 473 [D loss: 4.0700, acc.: 1.56%] [G loss: 0.0146]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 474 [D loss: 4.0717, acc.: 1.56%] [G loss: 0.0146]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 475 [D loss: 4.0739, acc.: 1.56%] [G loss: 0.0146]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 476 [D loss: 4.0761, acc.: 1.55%] [G loss: 0.0146]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 477 [D loss: 4.0784, acc.: 1.56%] [G loss: 0.0145]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 478 [D loss: 4.0804, acc.: 1.56%] [G loss: 0.0145]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 479 [D loss: 4.0825, acc.: 1.58%] [G loss: 0.0145]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 480 [D loss: 4.0844, acc.: 1.58%] [G loss: 0.0144]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 481 [D loss: 4.0862, acc.: 1.58%] [G loss: 0.0144]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 482 [D loss: 4.0881, acc.: 1.57%] [G loss: 0.0144]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 483 [D loss: 4.0900, acc.: 1.57%] [G loss: 0.0143]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 484 [D loss: 4.0920, acc.: 1.57%] [G loss: 0.0143]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 485 [D loss: 4.0939, acc.: 1.56%] [G loss: 0.0143]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 486 [D loss: 4.0959, acc.: 1.56%] [G loss: 0.0143]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 487 [D loss: 4.0974, acc.: 1.56%] [G loss: 0.0142]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 488 [D loss: 4.0989, acc.: 1.56%] [G loss: 0.0142]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 489 [D loss: 4.1008, acc.: 1.56%] [G loss: 0.0142]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 490 [D loss: 4.1025, acc.: 1.56%] [G loss: 0.0141]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 491 [D loss: 4.1040, acc.: 1.56%] [G loss: 0.0141]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 492 [D loss: 4.1058, acc.: 1.56%] [G loss: 0.0141]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 493 [D loss: 4.1079, acc.: 1.56%] [G loss: 0.0141]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 494 [D loss: 4.1099, acc.: 1.56%] [G loss: 0.0140]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 495 [D loss: 4.1118, acc.: 1.56%] [G loss: 0.0140]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 496 [D loss: 4.1137, acc.: 1.55%] [G loss: 0.0140]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 497 [D loss: 4.1156, acc.: 1.55%] [G loss: 0.0139]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 498 [D loss: 4.1174, acc.: 1.55%] [G loss: 0.0139]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 499 [D loss: 4.1191, acc.: 1.55%] [G loss: 0.0139]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 500 [D loss: 4.1210, acc.: 1.55%] [G loss: 0.0139]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 501 [D loss: 4.1230, acc.: 1.55%] [G loss: 0.0138]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 502 [D loss: 4.1250, acc.: 1.55%] [G loss: 0.0138]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 503 [D loss: 4.1268, acc.: 1.54%] [G loss: 0.0138]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 504 [D loss: 4.1288, acc.: 1.55%] [G loss: 0.0138]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 505 [D loss: 4.1309, acc.: 1.55%] [G loss: 0.0137]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 506 [D loss: 4.1328, acc.: 1.55%] [G loss: 0.0137]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 507 [D loss: 4.1347, acc.: 1.56%] [G loss: 0.0137]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 508 [D loss: 4.1365, acc.: 1.56%] [G loss: 0.0137]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 509 [D loss: 4.1386, acc.: 1.56%] [G loss: 0.0136]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 510 [D loss: 4.1408, acc.: 1.56%] [G loss: 0.0136]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 511 [D loss: 4.1426, acc.: 1.56%] [G loss: 0.0136]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 512 [D loss: 4.1446, acc.: 1.56%] [G loss: 0.0135]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 513 [D loss: 4.1466, acc.: 1.56%] [G loss: 0.0135]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 514 [D loss: 4.1483, acc.: 1.55%] [G loss: 0.0135]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 515 [D loss: 4.1501, acc.: 1.55%] [G loss: 0.0135]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 516 [D loss: 4.1515, acc.: 1.55%] [G loss: 0.0134]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 517 [D loss: 4.1530, acc.: 1.55%] [G loss: 0.0134]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 518 [D loss: 4.1550, acc.: 1.54%] [G loss: 0.0134]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 519 [D loss: 4.1569, acc.: 1.55%] [G loss: 0.0134]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 520 [D loss: 4.1587, acc.: 1.54%] [G loss: 0.0133]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 521 [D loss: 4.1605, acc.: 1.54%] [G loss: 0.0133]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 522 [D loss: 4.1625, acc.: 1.54%] [G loss: 0.0133]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 523 [D loss: 4.1645, acc.: 1.54%] [G loss: 0.0133]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 524 [D loss: 4.1666, acc.: 1.54%] [G loss: 0.0132]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 525 [D loss: 4.1684, acc.: 1.53%] [G loss: 0.0132]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 526 [D loss: 4.1700, acc.: 1.53%] [G loss: 0.0132]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 527 [D loss: 4.1718, acc.: 1.53%] [G loss: 0.0132]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 528 [D loss: 4.1735, acc.: 1.53%] [G loss: 0.0131]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 529 [D loss: 4.1750, acc.: 1.53%] [G loss: 0.0131]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 530 [D loss: 4.1767, acc.: 1.54%] [G loss: 0.0131]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 531 [D loss: 4.1786, acc.: 1.54%] [G loss: 0.0131]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 532 [D loss: 4.1807, acc.: 1.54%] [G loss: 0.0131]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 533 [D loss: 4.1827, acc.: 1.54%] [G loss: 0.0130]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 534 [D loss: 4.1844, acc.: 1.54%] [G loss: 0.0130]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 535 [D loss: 4.1862, acc.: 1.53%] [G loss: 0.0130]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 536 [D loss: 4.1880, acc.: 1.53%] [G loss: 0.0130]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 537 [D loss: 4.1897, acc.: 1.53%] [G loss: 0.0129]
# ...
# 735 [D loss: 4.4856, acc.: 1.51%] [G loss: 0.0095]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 736 [D loss: 4.4868, acc.: 1.51%] [G loss: 0.0095]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 737 [D loss: 4.4881, acc.: 1.50%] [G loss: 0.0095]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 738 [D loss: 4.4896, acc.: 1.50%] [G loss: 0.0095]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 739 [D loss: 4.4913, acc.: 1.50%] [G loss: 0.0094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 740 [D loss: 4.4929, acc.: 1.50%] [G loss: 0.0094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 741 [D loss: 4.4943, acc.: 1.50%] [G loss: 0.0094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 742 [D loss: 4.4955, acc.: 1.50%] [G loss: 0.0094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 743 [D loss: 4.4966, acc.: 1.50%] [G loss: 0.0094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 744 [D loss: 4.4978, acc.: 1.49%] [G loss: 0.0094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 745 [D loss: 4.4991, acc.: 1.50%] [G loss: 0.0094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 746 [D loss: 4.5003, acc.: 1.50%] [G loss: 0.0094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 747 [D loss: 4.5012, acc.: 1.50%] [G loss: 0.0094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 748 [D loss: 4.5019, acc.: 1.49%] [G loss: 0.0093]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 749 [D loss: 4.5029, acc.: 1.49%] [G loss: 0.0093]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 750 [D loss: 4.5041, acc.: 1.49%] [G loss: 0.0093]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 751 [D loss: 4.5050, acc.: 1.49%] [G loss: 0.0093]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 752 [D loss: 4.5061, acc.: 1.49%] [G loss: 0.0093]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 753 [D loss: 4.5073, acc.: 1.50%] [G loss: 0.0093]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 754 [D loss: 4.5086, acc.: 1.49%] [G loss: 0.0093]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 755 [D loss: 4.5099, acc.: 1.49%] [G loss: 0.0093]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 756 [D loss: 4.5113, acc.: 1.49%] [G loss: 0.0092]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 757 [D loss: 4.5126, acc.: 1.49%] [G loss: 0.0092]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 758 [D loss: 4.5139, acc.: 1.49%] [G loss: 0.0092]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 759 [D loss: 4.5154, acc.: 1.49%] [G loss: 0.0092]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 760 [D loss: 4.5167, acc.: 1.49%] [G loss: 0.0092]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 761 [D loss: 4.5181, acc.: 1.49%] [G loss: 0.0092]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 762 [D loss: 4.5198, acc.: 1.48%] [G loss: 0.0092]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 763 [D loss: 4.5212, acc.: 1.49%] [G loss: 0.0092]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 764 [D loss: 4.5228, acc.: 1.48%] [G loss: 0.0091]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 765 [D loss: 4.5241, acc.: 1.49%] [G loss: 0.0091]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 766 [D loss: 4.5251, acc.: 1.48%] [G loss: 0.0091]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 767 [D loss: 4.5263, acc.: 1.49%] [G loss: 0.0091]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 768 [D loss: 4.5275, acc.: 1.50%] [G loss: 0.0091]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 769 [D loss: 4.5287, acc.: 1.50%] [G loss: 0.0091]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 770 [D loss: 4.5301, acc.: 1.50%] [G loss: 0.0091]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 771 [D loss: 4.5315, acc.: 1.50%] [G loss: 0.0091]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 772 [D loss: 4.5328, acc.: 1.50%] [G loss: 0.0091]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 773 [D loss: 4.5340, acc.: 1.50%] [G loss: 0.0090]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 774 [D loss: 4.5354, acc.: 1.50%] [G loss: 0.0090]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 775 [D loss: 4.5368, acc.: 1.51%] [G loss: 0.0090]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 776 [D loss: 4.5381, acc.: 1.50%] [G loss: 0.0090]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 777 [D loss: 4.5391, acc.: 1.51%] [G loss: 0.0090]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 778 [D loss: 4.5403, acc.: 1.50%] [G loss: 0.0090]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 779 [D loss: 4.5419, acc.: 1.50%] [G loss: 0.0090]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 780 [D loss: 4.5434, acc.: 1.50%] [G loss: 0.0090]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 781 [D loss: 4.5447, acc.: 1.50%] [G loss: 0.0089]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 782 [D loss: 4.5459, acc.: 1.50%] [G loss: 0.0089]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 783 [D loss: 4.5472, acc.: 1.50%] [G loss: 0.0089]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 784 [D loss: 4.5484, acc.: 1.50%] [G loss: 0.0089]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 785 [D loss: 4.5495, acc.: 1.50%] [G loss: 0.0089]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 786 [D loss: 4.5506, acc.: 1.50%] [G loss: 0.0089]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 787 [D loss: 4.5520, acc.: 1.50%] [G loss: 0.0089]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 788 [D loss: 4.5534, acc.: 1.51%] [G loss: 0.0089]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 789 [D loss: 4.5545, acc.: 1.50%] [G loss: 0.0089]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 790 [D loss: 4.5555, acc.: 1.51%] [G loss: 0.0088]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 791 [D loss: 4.5567, acc.: 1.51%] [G loss: 0.0088]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 792 [D loss: 4.5580, acc.: 1.51%] [G loss: 0.0088]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 793 [D loss: 4.5592, acc.: 1.51%] [G loss: 0.0088]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 794 [D loss: 4.5604, acc.: 1.51%] [G loss: 0.0088]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 795 [D loss: 4.5618, acc.: 1.50%] [G loss: 0.0088]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 796 [D loss: 4.5631, acc.: 1.50%] [G loss: 0.0088]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 797 [D loss: 4.5639, acc.: 1.50%] [G loss: 0.0088]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 798 [D loss: 4.5648, acc.: 1.50%] [G loss: 0.0088]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 799 [D loss: 4.5658, acc.: 1.50%] [G loss: 0.0088]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 800 [D loss: 4.5669, acc.: 1.50%] [G loss: 0.0087]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 801 [D loss: 4.5682, acc.: 1.50%] [G loss: 0.0087]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 802 [D loss: 4.5694, acc.: 1.49%] [G loss: 0.0087]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 803 [D loss: 4.5706, acc.: 1.49%] [G loss: 0.0087]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 804 [D loss: 4.5716, acc.: 1.49%] [G loss: 0.0087]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 805 [D loss: 4.5726, acc.: 1.49%] [G loss: 0.0087]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 806 [D loss: 4.5738, acc.: 1.49%] [G loss: 0.0087]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 807 [D loss: 4.5749, acc.: 1.49%] [G loss: 0.0087]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 808 [D loss: 4.5762, acc.: 1.49%] [G loss: 0.0087]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 809 [D loss: 4.5775, acc.: 1.49%] [G loss: 0.0086]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 810 [D loss: 4.5788, acc.: 1.49%] [G loss: 0.0086]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 811 [D loss: 4.5800, acc.: 1.49%] [G loss: 0.0086]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 812 [D loss: 4.5812, acc.: 1.49%] [G loss: 0.0086]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 813 [D loss: 4.5824, acc.: 1.49%] [G loss: 0.0086]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 814 [D loss: 4.5837, acc.: 1.49%] [G loss: 0.0086]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 815 [D loss: 4.5849, acc.: 1.49%] [G loss: 0.0086]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 816 [D loss: 4.5860, acc.: 1.49%] [G loss: 0.0086]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 817 [D loss: 4.5871, acc.: 1.49%] [G loss: 0.0086]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 818 [D loss: 4.5881, acc.: 1.48%] [G loss: 0.0085]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 819 [D loss: 4.5891, acc.: 1.49%] [G loss: 0.0085]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 820 [D loss: 4.5905, acc.: 1.48%] [G loss: 0.0085]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 821 [D loss: 4.5919, acc.: 1.49%] [G loss: 0.0085]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 822 [D loss: 4.5932, acc.: 1.49%] [G loss: 0.0085]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 823 [D loss: 4.5946, acc.: 1.49%] [G loss: 0.0085]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 824 [D loss: 4.5958, acc.: 1.49%] [G loss: 0.0085]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 825 [D loss: 4.5968, acc.: 1.50%] [G loss: 0.0085]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 826 [D loss: 4.5981, acc.: 1.50%] [G loss: 0.0085]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 827 [D loss: 4.5995, acc.: 1.50%] [G loss: 0.0085]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 828 [D loss: 4.6006, acc.: 1.50%] [G loss: 0.0084]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 829 [D loss: 4.6018, acc.: 1.50%] [G loss: 0.0084]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 830 [D loss: 4.6031, acc.: 1.50%] [G loss: 0.0084]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 831 [D loss: 4.6043, acc.: 1.50%] [G loss: 0.0084]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 832 [D loss: 4.6054, acc.: 1.50%] [G loss: 0.0084]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 833 [D loss: 4.6066, acc.: 1.50%] [G loss: 0.0084]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 834 [D loss: 4.6078, acc.: 1.50%] [G loss: 0.0084]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 835 [D loss: 4.6088, acc.: 1.50%] [G loss: 0.0084]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 836 [D loss: 4.6098, acc.: 1.50%] [G loss: 0.0084]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 837 [D loss: 4.6109, acc.: 1.50%] [G loss: 0.0084]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 838 [D loss: 4.6119, acc.: 1.50%] [G loss: 0.0083]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 839 [D loss: 4.6131, acc.: 1.50%] [G loss: 0.0083]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 840 [D loss: 4.6143, acc.: 1.50%] [G loss: 0.0083]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 841 [D loss: 4.6156, acc.: 1.50%] [G loss: 0.0083]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 842 [D loss: 4.6168, acc.: 1.50%] [G loss: 0.0083]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 843 [D loss: 4.6179, acc.: 1.50%] [G loss: 0.0083]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 844 [D loss: 4.6191, acc.: 1.49%] [G loss: 0.0083]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 845 [D loss: 4.6201, acc.: 1.49%] [G loss: 0.0083]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 846 [D loss: 4.6211, acc.: 1.49%] [G loss: 0.0083]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 847 [D loss: 4.6224, acc.: 1.49%] [G loss: 0.0083]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 848 [D loss: 4.6238, acc.: 1.49%] [G loss: 0.0083]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 849 [D loss: 4.6252, acc.: 1.49%] [G loss: 0.0082]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 850 [D loss: 4.6266, acc.: 1.49%] [G loss: 0.0082]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 851 [D loss: 4.6278, acc.: 1.49%] [G loss: 0.0082]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 852 [D loss: 4.6290, acc.: 1.49%] [G loss: 0.0082]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 853 [D loss: 4.6302, acc.: 1.49%] [G loss: 0.0082]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 854 [D loss: 4.6313, acc.: 1.49%] [G loss: 0.0082]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 855 [D loss: 4.6323, acc.: 1.49%] [G loss: 0.0082]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 856 [D loss: 4.6334, acc.: 1.48%] [G loss: 0.0082]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 857 [D loss: 4.6346, acc.: 1.48%] [G loss: 0.0082]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 858 [D loss: 4.6359, acc.: 1.48%] [G loss: 0.0082]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4066759114.py in <cell line: 0>()
#     158 # 6. Run Training
#     159 # =============================
# --> 160 train(images, epochs=2000, batch_size=32, sample_interval=200)
#
# /tmp/ipython-input-4066759114.py in train(dataset, epochs, batch_size, sample_interval)
#     146         noise = np.random.normal(0, 1, (batch_size, latent_dim))
#     147         valid_y = np.ones((batch_size, 1))
# --> 148         g_loss = combined.train_on_batch(noise, valid_y)
#     149
#     150         # Print Progress
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in train_on_batch(self, x, y, sample_weight, class_weight, return_dict)
#     603             yield (x, y, sample_weight)
#     604
# --> 605         logs = self.train_function(data())
#     606         logs = tree.map_structure(lambda x: np.array(x), logs)
#     607         if return_dict:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     226                     range(self.steps_per_execution), iterator
#     227                 ):
# --> 228                     outputs = one_step_on_data(data)
#     229                 return outputs
#     230
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     867       # In this case we have created variables on the first call, so we run the
#     868       # defunned version which is guaranteed to never create variables.
# --> 869       return tracing_compilation.call_function(
#     870           args, kwds, self._no_variable_creation_config
#     871       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
from PIL import Image, ImageDraw

def generate_kolam(n, spacing=70, margin=50, dot_radius=4, stroke_width=3, filename='kolam.png'):
    """
    Generate a kolam-like image using a grid of n x n dots.
    """
    # Calculate image size
    width = margin*2 + spacing*(n-1)
    height = margin*2 + spacing*(n-1)
    img = Image.new('RGB', (width, height), 'white')
    draw = ImageDraw.Draw(img)

    # Compute dot coordinates
    coords = []
    for r in range(n):
        row = []
        for c in range(n):
            x = margin + c * spacing
            y = margin + r * spacing
            row.append((x, y))
            # Draw dot
            draw.ellipse((x-dot_radius, y-dot_radius, x+dot_radius, y+dot_radius), fill='black')
        coords.append(row)

    # Draw horizontal semicircles
    for r in range(n):
        for c in range(n-1):
            x1, y1 = coords[r][c]
            x2, y2 = coords[r][c+1]
            left = x1
            top = y1 - spacing//2
            right = x2
            bottom = y1 + spacing//2
            if r % 2 == 0:
                start, end = 180, 360  # lower semicircle
            else:
                start, end = 0, 180    # upper semicircle
            draw.arc([left, top, right, bottom], start=start, end=end, width=stroke_width, fill='black')

    # Draw vertical semicircles
    for c in range(n):
        for r in range(n-1):
            x1, y1 = coords[r][c]
            x2, y2 = coords[r+1][c]
            left = x1 - spacing//2
            top = y1
            right = x1 + spacing//2
            bottom = y2
            if c % 2 == 0:
                start, end = 90, 270   # left semicircle
            else:
                start, end = -90, 90   # right semicircle
            draw.arc([left, top, right, bottom], start=start, end=end, width=stroke_width, fill='black')

    # Add inner loops for complexity
    for r in range(n-1):
        for c in range(n-1):
            cx = (coords[r][c][0] + coords[r][c+1][0] + coords[r+1][c][0] + coords[r+1][c+1][0]) / 4
            cy = (coords[r][c][1] + coords[r][c+1][1] + coords[r+1][c][1] + coords[r+1][c+1][1]) / 4
            radius = spacing * 0.12
            draw.ellipse((cx-radius, cy-radius, cx+radius, cy+radius), outline='black', width=2)

    img.save(filename)
    print(f"✅ Kolam saved as {filename}")


# ---------- USER INPUT ----------
if __name__ == "__main__":
    n = int(input("Enter number of dots per row/column: "))
    spacing = int(input("Enter spacing between dots (e.g., 50, 60, 70): "))
    margin = int(input("Enter margin size (default 50): ") or 50)
    filename = input("Enter filename to save (default kolam.png): ") or "kolam.png"
    print("\n")
    print("No. of Dots per Row: ",n)
    print("Space between Dots: ",spacing)
    print("Margin Size: ",margin)


    generate_kolam(n, spacing=spacing, margin=margin, filename=filename)
# Out:
# Enter number of dots per row/column: 11
# Enter spacing between dots (e.g., 50, 60, 70): 90
# Enter margin size (default 50): 70
# Enter filename to save (default kolam.png): fig.png
#
#
# No. of Dots per Row:  11
# Space between Dots:  90
# Margin Size:  70
# ✅ Kolam saved as fig.png

# %%
import gradio as gr
from PIL import Image, ImageDraw

def generate_kolam(n, spacing=70, margin=50, dot_radius=4, stroke_width=3):
    """
    Generate a kolam-like image using a grid of n x n dots.
    """
    # Calculate image size
    width = margin*2 + spacing*(n-1)
    height = margin*2 + spacing*(n-1)
    img = Image.new('RGB', (width, height), 'white')
    draw = ImageDraw.Draw(img)

    # Compute dot coordinates
    coords = []
    for r in range(n):
        row = []
        for c in range(n):
            x = margin + c * spacing
            y = margin + r * spacing
            row.append((x, y))
            # Draw dot
            draw.ellipse((x-dot_radius, y-dot_radius, x+dot_radius, y+dot_radius), fill='black')
        coords.append(row)

    # Draw horizontal semicircles
    for r in range(n):
        for c in range(n-1):
            x1, y1 = coords[r][c]
            x2, y2 = coords[r][c+1]
            left = x1
            top = y1 - spacing//2
            right = x2
            bottom = y1 + spacing//2
            if r % 2 == 0:
                start, end = 180, 360  # lower semicircle
            else:
                start, end = 0, 180    # upper semicircle
            draw.arc([left, top, right, bottom], start=start, end=end, width=stroke_width, fill='black')

    # Draw vertical semicircles
    for c in range(n):
        for r in range(n-1):
            x1, y1 = coords[r][c]
            x2, y2 = coords[r+1][c]
            left = x1 - spacing//2
            top = y1
            right = x1 + spacing//2
            bottom = y2
            if c % 2 == 0:
                start, end = 90, 270   # left semicircle
            else:
                start, end = -90, 90   # right semicircle
            draw.arc([left, top, right, bottom], start=start, end=end, width=stroke_width, fill='black')

    # Add inner loops for complexity
    for r in range(n-1):
        for c in range(n-1):
            cx = (coords[r][c][0] + coords[r][c+1][0] + coords[r+1][c][0] + coords[r+1][c+1][0]) / 4
            cy = (coords[r][c][1] + coords[r][c+1][1] + coords[r+1][c][1] + coords[r+1][c+1][1]) / 4
            radius = spacing * 0.12
            draw.ellipse((cx-radius, cy-radius, cx+radius, cy+radius), outline='black', width=2)

    return img


# ----------------- GRADIO UI -----------------
def kolam_ui(n, spacing, margin):
    return generate_kolam(n, spacing=spacing, margin=margin)

with gr.Blocks() as demo:
    gr.Markdown("## 🎨 Kolam Generator\nGenerate symmetric Kolam patterns with dots and curves.")

    with gr.Row():
        n = gr.Slider(3, 15, value=7, step=1, label="Number of Dots per Row/Column")
        spacing = gr.Slider(40, 100, value=70, step=5, label="Spacing Between Dots")
        margin = gr.Slider(20, 100, value=50, step=5, label="Margin Size")

    btn = gr.Button("Generate Kolam")
    output = gr.Image(type="pil", label="Generated Kolam")

    btn.click(fn=kolam_ui, inputs=[n, spacing, margin], outputs=output)

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://5163a716de4073aa68.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5163a716de4073aa68.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
